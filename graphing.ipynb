# %%
from collections import defaultdict
import pandas as pd
import pprint

# %%
g = defaultdict(list)

marry = pd.read_csv('data/marriages.csv')
kids = pd.read_csv('data/children.csv')
chars = pd.read_csv('data/characters.csv')

# %%
for i, row in marry.iterrows():
    if pd.isna(row.MarryOptions):
        continue
    options = row.MarryOptions.split('-')
    for o in options:
        g[row.Character].append(o)
        g[o].append(row.Character)

# %%
for i, row in kids.iterrows():
    g[row.Child].append(row.Main)
    g[row.Main].append(row.Child)

# %%
for i, row in chars.iterrows():
    options = row.OptionsList.split('-')
    for o in options:
        g[row.Name].append(o)

# %%
def find_path(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return path
    if not graph.get(start, None):
        return None
    for node in graph[start]:
        if node not in path:
            newpath = find_path(graph, node, end, path)
            if newpath: return newpath
    return None

# %%
def find_all_paths(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if not graph.get(start, None):
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            newpaths = find_all_paths(graph, node, end, path)
            for newpath in newpaths:
                paths.append(newpath)
    return paths

# %%
def find_shortest_path(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return path
    if not graph.get(start, None):
        return None
    shortest = None
    for node in graph[start]:
        if node not in path:
            newpath = find_shortest_path(graph, node, end, path)
            if newpath:
                if not shortest or len(newpath) < len(shortest):
                    shortest = newpath
    return shortest

# %%
find_path(g, 'Lucina', 'Pegasus Knight')
# Out:
# ['Lucina',
#  'Owain',
#  'Kjelle',
#  'Inigo',
#  'Cynthia',
#  'Brady',
#  'Severa',
#  'Gerome',
#  'Morgan (F)',
#  'Yarne',
#  'Noire',
#  'Morgan (M)',
#  'Nah',
#  'Laurent',
#  'Miriel',
#  'Frederick',
#  'Sumia',
#  'Chrom',
#  'Sully',
#  'Virion',
#  'Lissa',
#  'Stahl',
#  'Maribelle',
#  'Vaike',
#  'Panne',
#  'Kellam',
#  'Cordelia',
#  'Lonqu',
#  'Nowi',
#  'Ricken',
#  'Tharja',
#  'Gaius',
#  'Olivia',
#  'Pegasus Knight']

# %%
find_shortest_path(g, 'Lucina', 'Pegasus Knight')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-0d0724e5bd63> in <module>
# ----> 1 find_shortest_path(g, 'Lucina', 'Pegasus Knight')
#
# <ipython-input-56-2c51bc2b926d> in find_shortest_path(graph, start, end, path)
#       8     for node in graph[start]:
#       9         if node not in path:
# ---> 10             newpath = find_shortest_path(graph, node, end, path)
#      11             if newpath:
#      12                 if not shortest or len(newpath) < len(shortest):
#
# <ipython-input-56-2c51bc2b926d> in find_shortest_path(graph, start, end, path)
#       8     for node in graph[start]:
#       9         if node not in path:
# ---> 10             newpath = find_shortest_path(graph, node, end, path)
#      11             if newpath:
#      12                 if not shortest or len(newpath) < len(shortest):
#
# ...

# %%
find_all_paths(g, 'Chrom', 'Pegasus Knight')

# %%
pprint.pprint(g)
# Out:
# defaultdict(<class 'list'>,
#             {'Anna': ['Thief', 'Archer', 'Mage'],
#              'Avatar (F)': ['Chrom',
#                             'Morgan (M)',
#                             'Tactician',
#                             'Knight',
#                             'Cavalier',
#                             'Archer',
#                             'Myrmidon',
#                             'Mercenary',
#                             'Mage',
#                             'Dark Mage',
#                             'Thief',
#                             'Pegasus Knight',
#                             'Wyvern Rider',
#                             'Cleric',
#                             'Troubadour'],
#              'Avatar (M)': ['Morgan (F)',
#                             'Tactician',
#                             'Knight',
#                             'Cavalier',
#                             'Archer',
#                             'Myrmidon',
# ...
